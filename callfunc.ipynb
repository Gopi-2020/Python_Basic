# %%
from callfunctions import multipleones

# %%
multipleones.Percentage()
# Out:
# Enter the sub1 mark: 87
# Enter the sub2 mark: 89
# Enter the sub3 mark: 87
# Enter the sub4 mark: 56
# Enter the sub5 mark: 87
# Total: 406
# Percentage: 81.2
# 81.2

# %%
multipleones.Triangle()
# Out:
# Enter the Height: 89
# Enter the breadth: 75
# Area of Triangle: 3337.5
# Enter the Height1: 5
# Enter the Height2: 6
# Enter the Breadth1: 1
# Perimeter of triangle: 12

# %%
multipleones.Eligiblemarriage()
# Out:
# Enter the Male age: 25
# YOUR GENDER: Male
# YOUR AGE: 25
# Eligible
# Enter the Female age: 21
# YOUR GENDER: FEMALE
# YOUR AGE: 21
# Elgible
